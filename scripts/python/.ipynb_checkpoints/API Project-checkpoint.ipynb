# %% [markdown]
# # API Project - Bus Bunching
# ### Multi-agency Comparsion (WMATA, MBTA, MTA)
# Question: What route and temporal factors are associated with bus bunching on high-frequency corridors, and do these relationships vary across different transit agencies (NYC, Boston, and DC)?

# %%
import pandas as pd
import numpy as np
import requests
import ratelim
import tenacity

# %% [markdown]
# ### 1) WMATA API
# #### Bus Routes: D40, D60, D80, C53, C61, D20

# %%
WMATA_KEY = "5ec08fcd21744590b1a0f655710c4c91"

# %%
wmata_url = "https://api.wmata.com/Bus.svc/json/jBusPositions"
wmata_params = {"RouteID": "D40"}  
wmata_headers = {"api_key": WMATA_KEY}

requests.get(wmata_url, params=wmata_params, headers=wmata_headers)
# Out:
# <Response [200]>

# %%
wmata_response = requests.get(wmata_url, params=wmata_params, headers=wmata_headers)
wmata_response.json()
# Out:
# {'BusPositions': [{'VehicleID': '5514',
#    'Lat': 38.99368836449795,
#    'Lon': -77.03037011818807,
#    'Deviation': 5.0,
#    'DateTime': '2026-03-26T14:17:01',
#    'TripID': '30634020',
#    'RouteID': 'D40',
#    'DirectionNum': 0,
#    'DirectionText': 'NORTH',
#    'TripHeadsign': 'SILVER SPRING',
#    'TripStartTime': '2026-03-26T13:12:00',
#    'TripEndTime': '2026-03-26T14:09:00',
#    'BlockNumber': 'M618'},
#   {'VehicleID': '5533',
#    'Lat': 38.89541855980368,
#    'Lon': -77.02191162109375,
#    'Deviation': 2.0,
#    'DateTime': '2026-03-26T14:16:42',
#    'TripID': '25675020',
#    'RouteID': 'D40',
#    'DirectionNum': 1,
#    'DirectionText': 'SOUTH',
#    'TripHeadsign': 'ARCHIVES',
#    'TripStartTime': '2026-03-26T13:12:00',
#    'TripEndTime': '2026-03-26T14:18:00',
#    'BlockNumber': 'M608'},
#   {'VehicleID': '5505',
#    'Lat': 38.91591188019397,
#    'Lon': -77.02191925048828,
#    'Deviation': 6.0,
#    'DateTime': '2026-03-26T14:16:39',
#    'TripID': '33133020',
#    'RouteID': 'D40',
#    'DirectionNum': 1,
#    'DirectionText': 'SOUTH',
#    'TripHeadsign': 'ARCHIVES',
#    'TripStartTime': '2026-03-26T13:24:00',
#    'TripEndTime': '2026-03-26T14:30:00',
#    'BlockNumber': 'M622'},
#   {'VehicleID': '5525',
#    'Lat': 38.96152400970459,
#    'Lon': -77.02792072296143,
#    'Deviation': 14.0,
#    'DateTime': '2026-03-26T14:17:00',
#    'TripID': '2454020',
#    'RouteID': 'D40',
#    'DirectionNum': 0,
#    'DirectionText': 'NORTH',
#    'TripHeadsign': 'SILVER SPRING',
#    'TripStartTime': '2026-03-26T13:24:00',
#    'TripEndTime': '2026-03-26T14:21:00',
#    'BlockNumber': 'M615'},
#   {'VehicleID': '5506',
#    'Lat': 38.96044819529464,
#    'Lon': -77.02808342910394,
#    'Deviation': 2.0,
#    'DateTime': '2026-03-26T14:16:38',
#    'TripID': '17379020',
#    'RouteID': 'D40',
#    'DirectionNum': 0,
#    'DirectionText': 'NORTH',
#    'TripHeadsign': 'SILVER SPRING',
#    'TripStartTime': '2026-03-26T13:36:00',
#    'TripEndTime': '2026-03-26T14:33:00',
#    'BlockNumber': 'M606'},
#   {'VehicleID': '5515',
#    'Lat': 38.94456402760632,
#    'Lon': -77.02620984923165,
#    'Deviation': 11.0,
#    'DateTime': '2026-03-26T14:16:55',
#    'TripID': '119020',
#    'RouteID': 'D40',
#    'DirectionNum': 1,
#    'DirectionText': 'SOUTH',
#    'TripHeadsign': 'ARCHIVES',
#    'TripStartTime': '2026-03-26T13:36:00',
#    'TripEndTime': '2026-03-26T14:42:00',
#    'BlockNumber': 'M604'},
#   {'VehicleID': '5501',
#    'Lat': 38.94330314967943,
#    'Lon': -77.0258848770805,
#    'Deviation': -2.0,
#    'DateTime': '2026-03-26T14:17:03',
#    'TripID': '18173020',
#    'RouteID': 'D40',
#    'DirectionNum': 1,
#    'DirectionText': 'SOUTH',
#    'TripHeadsign': 'ARCHIVES',
#    'TripStartTime': '2026-03-26T13:48:00',
#    'TripEndTime': '2026-03-26T14:54:00',
#    'BlockNumber': 'M612'},
#   {'VehicleID': '5532',
#    'Lat': 38.93525756032843,
#    'Lon': -77.02414623059724,
#    'Deviation': 2.0,
#    'DateTime': '2026-03-26T14:16:41',
#    'TripID': '11740020',
#    'RouteID': 'D40',
#    'DirectionNum': 0,
#    'DirectionText': 'NORTH',
#    'TripHeadsign': 'SILVER SPRING',
#    'TripStartTime': '2026-03-26T13:48:00',
#    'TripEndTime': '2026-03-26T14:45:00',
#    'BlockNumber': 'M619'},
#   {'VehicleID': '5522',
#    'Lat': 38.90190124511719,
#    'Lon': -77.02185974121093,
#    'Deviation': 10.0,
#    'DateTime': '2026-03-26T14:17:03',
#    'TripID': '12357020',
#    'RouteID': 'D40',
#    'DirectionNum': 0,
#    'DirectionText': 'NORTH',
#    'TripHeadsign': 'SILVER SPRING',
#    'TripStartTime': '2026-03-26T14:00:00',
#    'TripEndTime': '2026-03-26T14:57:00',
#    'BlockNumber': 'M620'},
#   {'VehicleID': '5519',
#    'Lat': 38.96155513416637,
#    'Lon': -77.0280269276012,
#    'Deviation': -4.0,
#    'DateTime': '2026-03-26T14:16:50',
#    'TripID': '14335020',
#    'RouteID': 'D40',
#    'DirectionNum': 1,
#    'DirectionText': 'SOUTH',
#    'TripHeadsign': 'ARCHIVES',
#    'TripStartTime': '2026-03-26T14:00:00',
#    'TripEndTime': '2026-03-26T15:06:00',
#    'BlockNumber': 'M603'},
#   {'VehicleID': '5503',
#    'Lat': 38.89457427130805,
#    'Lon': -77.02191925048828,
#    'Deviation': 3.0,
#    'DateTime': '2026-03-26T14:16:45',
#    'TripID': '17376020',
#    'RouteID': 'D40',
#    'DirectionNum': 0,
#    'DirectionText': 'NORTH',
#    'TripHeadsign': 'SILVER SPRING',
#    'TripStartTime': '2026-03-26T14:12:00',
#    'TripEndTime': '2026-03-26T15:09:00',
#    'BlockNumber': 'M610'},
#   {'VehicleID': '5536',
#    'Lat': 38.99407222659089,
#    'Lon': -77.02916912699855,
#    'Deviation': 4.0,
#    'DateTime': '2026-03-26T14:16:49',
#    'TripID': '21516020',
#    'RouteID': 'D40',
#    'DirectionNum': 1,
#    'DirectionText': 'SOUTH',
#    'TripHeadsign': 'ARCHIVES',
#    'TripStartTime': '2026-03-26T14:12:00',
#    'TripEndTime': '2026-03-26T15:18:00',
#    'BlockNumber': 'M614'}]}

# %% [markdown]
# #### Vars Used:
# - `Deviation` — the primary outcome, minutes late/early so no GTFS needed
# - `DateTime` — timestamp will be used for peak hour flag
# - `RouteID`, `DirectionNum`, `VehicleID`, `TripID` — route/trip identifiers (`DirectionNum`, 0=North 1=South)
# - `TripStartTime` — scheduled headway, will be used to calc the gap between consecutive trips
# - `Lat`, `Lon` — Vehicle position

# %%
wmata_fields = {
    'VehicleID': 'vehicle_id',
    'Lat': 'lat',
    'Lon': 'lon',
    'Deviation': 'deviation',
    'DateTime': 'timestamp',
    'TripID': 'trip_id',
    'RouteID': 'route_id',
    'DirectionNum': 'direction',
    'TripStartTime': 'trip_start_time'
}

wmata_positions = wmata_response.json()['BusPositions']

df = pd.DataFrame(wmata_positions)[list(wmata_fields.keys())].rename(columns=wmata_fields)
df['agency'] = 'WMATA'

print(df)
print(df.dtypes) #Checks for var types (timestamp and trip_start_time)
# Out:
#    vehicle_id        lat        lon  deviation            timestamp   trip_id  \
# 0        5514  38.993688 -77.030370        5.0  2026-03-26T14:17:01  30634020
# 1        5533  38.895419 -77.021912        2.0  2026-03-26T14:16:42  25675020
# 2        5505  38.915912 -77.021919        6.0  2026-03-26T14:16:39  33133020
# 3        5525  38.961524 -77.027921       14.0  2026-03-26T14:17:00   2454020
# 4        5506  38.960448 -77.028083        2.0  2026-03-26T14:16:38  17379020
# 5        5515  38.944564 -77.026210       11.0  2026-03-26T14:16:55    119020
# 6        5501  38.943303 -77.025885       -2.0  2026-03-26T14:17:03  18173020
# 7        5532  38.935258 -77.024146        2.0  2026-03-26T14:16:41  11740020
# 8        5522  38.901901 -77.021860       10.0  2026-03-26T14:17:03  12357020
# 9        5519  38.961555 -77.028027       -4.0  2026-03-26T14:16:50  14335020
# 10       5503  38.894574 -77.021919        3.0  2026-03-26T14:16:45  17376020
# 11       5536  38.994072 -77.029169        4.0  2026-03-26T14:16:49  21516020
#
#    route_id  direction      trip_start_time agency
# 0       D40          0  2026-03-26T13:12:00  WMATA
# 1       D40          1  2026-03-26T13:12:00  WMATA
# 2       D40          1  2026-03-26T13:24:00  WMATA
# 3       D40          0  2026-03-26T13:24:00  WMATA
# 4       D40          0  2026-03-26T13:36:00  WMATA
# 5       D40          1  2026-03-26T13:36:00  WMATA
# 6       D40          1  2026-03-26T13:48:00  WMATA
# 7       D40          0  2026-03-26T13:48:00  WMATA
# 8       D40          0  2026-03-26T14:00:00  WMATA
# 9       D40          1  2026-03-26T14:00:00  WMATA
# 10      D40          0  2026-03-26T14:12:00  WMATA
# 11      D40          1  2026-03-26T14:12:00  WMATA
# vehicle_id          object
# lat                float64
# lon                float64
# deviation          float64
# timestamp           object
# trip_id             object
# route_id            object
# direction            int64
# trip_start_time     object
# agency              object
# dtype: object

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['trip_start_time'] = pd.to_datetime(df['trip_start_time'])
print(df.dtypes)
# Out:
# vehicle_id                 object
# lat                       float64
# lon                       float64
# deviation                 float64
# timestamp          datetime64[ns]
# trip_id                    object
# route_id                   object
# direction                   int64
# trip_start_time    datetime64[ns]
# agency                     object
# dtype: object

# %%
routes = ['D40', 'D60', 'D80', 'C53', 'C61', 'D20']
dfs = []

for route in routes:
    wmata_response = requests.get(wmata_url, params={"RouteID": route}, headers=wmata_headers)
    wmata_positions = wmata_response.json()['BusPositions']
    df = pd.DataFrame(wmata_positions)[list(wmata_fields.keys())].rename(columns=wmata_fields)
    df['agency'] = 'WMATA'
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df['trip_start_time'] = pd.to_datetime(df['trip_start_time'])
    dfs.append(df)

wmata_df = pd.concat(dfs, ignore_index=True)

# %%
wmata_df
# Out:
#    vehicle_id        lat        lon  deviation           timestamp   trip_id  \
# 0        5514  38.993688 -77.030370        5.0 2026-03-26 14:17:01  30634020
# 1        5533  38.895419 -77.021912        2.0 2026-03-26 14:16:42  25675020
# 2        5505  38.915912 -77.021919        6.0 2026-03-26 14:16:39  33133020
# 3        5525  38.961524 -77.027921       14.0 2026-03-26 14:17:00   2454020
# 4        5506  38.960448 -77.028083        2.0 2026-03-26 14:16:38  17379020
# ..        ...        ...        ...        ...                 ...       ...
# 61       7204  38.900247 -77.009155        5.0 2026-03-26 14:17:01  10787020
# 62       5484  38.900227 -76.986349       -1.0 2026-03-26 14:16:53   3835020
# 63       5486  38.899818 -77.020211        6.0 2026-03-26 14:16:41   7603020
# 64       5487  38.900222 -76.998013       -1.0 2026-03-26 14:16:53  16076020
# 65       5482  38.899834 -77.028811        1.0 2026-03-26 14:17:01  21590020
#
#    route_id  direction     trip_start_time agency
# 0       D40          0 2026-03-26 13:12:00  WMATA
# 1       D40          1 2026-03-26 13:12:00  WMATA
# 2       D40          1 2026-03-26 13:24:00  WMATA
# 3       D40          0 2026-03-26 13:24:00  WMATA
# 4       D40          0 2026-03-26 13:36:00  WMATA
# ..      ...        ...                 ...    ...
# 61      D20          1 2026-03-26 13:50:00  WMATA
# 62      D20          0 2026-03-26 13:50:00  WMATA
# 63      D20          0 2026-03-26 14:00:00  WMATA
# 64      D20          1 2026-03-26 14:00:00  WMATA
# 65      D20          0 2026-03-26 14:10:00  WMATA
#
# [66 rows x 10 columns]

# %%
print(wmata_df['route_id'].unique()) #Checking that all the routes i need are in the df
# Out:
# ['D40' 'D60' 'D80' 'C53' 'C61' 'D20']

# %% [markdown]
# ### 2) MBTA API
# #### Bus Routes: Route 1, 23, 28, 39, 57, 66

# %%
MBTA_KEY = '4aa18b9edd1341e383dc8fe55a788cca'

# %%
#Test
mbta_url = "https://api-v3.mbta.com/vehicles"
mbta_params = {"filter[route]": "1"}
mbta_headers = {"x-api-key": MBTA_KEY}

requests.get(mbta_url, params=mbta_params, headers=mbta_headers)
# Out:
# <Response [200]>

# %%
mbta_response = requests.get(mbta_url, params=mbta_params, headers=mbta_headers)
mbta_response.json()
# Out:
# {'data': [{'attributes': {'bearing': 90,
#     'carriages': [],
#     'current_status': 'STOPPED_AT',
#     'current_stop_sequence': 1,
#     'direction_id': 0,
#     'label': '1922',
#     'latitude': 42.329788,
#     'longitude': -71.083408,
#     'occupancy_status': 'MANY_SEATS_AVAILABLE',
#     'revenue': 'REVENUE',
#     'speed': None,
#     'updated_at': '2026-03-26T14:35:57-04:00'},
#    'id': 'y1922',
#    'links': {'self': '/vehicles/y1922'},
#    'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#     'stop': {'data': {'id': '64', 'type': 'stop'}},
#     'trip': {'data': {'id': '73604109', 'type': 'trip'}}},
#    'type': 'vehicle'},
#   {'attributes': {'bearing': 340,
#     'carriages': [],
#     'current_status': 'IN_TRANSIT_TO',
#     'current_stop_sequence': 15,
#     'direction_id': 0,
#     'label': '1902',
#     'latitude': 42.353558,
#     'longitude': -71.090813,
#     'occupancy_status': 'FULL',
#     'revenue': 'REVENUE',
#     'speed': None,
#     'updated_at': '2026-03-26T14:36:01-04:00'},
#    'id': 'y1902',
#    'links': {'self': '/vehicles/y1902'},
#    'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#     'stop': {'data': {'id': '97', 'type': 'stop'}},
#     'trip': {'data': {'id': '73601851', 'type': 'trip'}}},
#    'type': 'vehicle'},
#   {'attributes': {'bearing': 136,
#     'carriages': [],
#     'current_status': 'IN_TRANSIT_TO',
#     'current_stop_sequence': 9,
#     'direction_id': 1,
#     'label': '1871',
#     'latitude': 42.361038,
#     'longitude': -71.096503,
#     'occupancy_status': 'FEW_SEATS_AVAILABLE',
#     'revenue': 'REVENUE',
#     'speed': None,
#     'updated_at': '2026-03-26T14:36:01-04:00'},
#    'id': 'y1871',
#    'links': {'self': '/vehicles/y1871'},
#    'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#     'stop': {'data': {'id': '74', 'type': 'stop'}},
#     'trip': {'data': {'id': '73604110', 'type': 'trip'}}},
#    'type': 'vehicle'},
#   {'attributes': {'bearing': 180,
#     'carriages': [],
#     'current_status': 'IN_TRANSIT_TO',
#     'current_stop_sequence': 12,
#     'direction_id': 1,
#     'label': '1846',
#     'latitude': 42.348345,
#     'longitude': -71.088363,
#     'occupancy_status': 'FEW_SEATS_AVAILABLE',
#     'revenue': 'REVENUE',
#     'speed': None,
#     'updated_at': '2026-03-26T14:36:01-04:00'},
#    'id': 'y1846',
#    'links': {'self': '/vehicles/y1846'},
#    'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#     'stop': {'data': {'id': '79', 'type': 'stop'}},
#     'trip': {'data': {'id': '73604078', 'type': 'trip'}}},
#    'type': 'vehicle'},
#   {'attributes': {'bearing': 135,
#     'carriages': [],
#     'current_status': 'STOPPED_AT',
#     'current_stop_sequence': 18,
#     'direction_id': 1,
#     'label': '1828',
#     'latitude': 42.33513,
#     'longitude': -71.07535,
#     'occupancy_status': 'FEW_SEATS_AVAILABLE',
#     'revenue': 'REVENUE',
#     'speed': None,
#     'updated_at': '2026-03-26T14:35:49-04:00'},
#    'id': 'y1828',
#    'links': {'self': '/vehicles/y1828'},
#    'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#     'stop': {'data': {'id': '854', 'type': 'stop'}},
#     'trip': {'data': {'id': '73604095', 'type': 'trip'}}},
#    'type': 'vehicle'},
#   {'attributes': {'bearing': 270,
#     'carriages': [],
#     'current_status': 'STOPPED_AT',
#     'current_stop_sequence': 1,
#     'direction_id': 1,
#     'label': '1825',
#     'latitude': 42.37309,
#     'longitude': -71.11775,
#     'occupancy_status': 'MANY_SEATS_AVAILABLE',
#     'revenue': 'REVENUE',
#     'speed': None,
#     'updated_at': '2026-03-26T14:35:59-04:00'},
#    'id': 'y1825',
#    'links': {'self': '/vehicles/y1825'},
#    'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#     'stop': {'data': {'id': '110', 'type': 'stop'}},
#     'trip': {'data': {'id': '73604084', 'type': 'trip'}}},
#    'type': 'vehicle'},
#   {'attributes': {'bearing': 340,
#     'carriages': [],
#     'current_status': 'IN_TRANSIT_TO',
#     'current_stop_sequence': 13,
#     'direction_id': 0,
#     'label': '1797',
#     'latitude': 42.346898,
#     'longitude': -71.087537,
#     'occupancy_status': 'FEW_SEATS_AVAILABLE',
#     'revenue': 'REVENUE',
#     'speed': None,
#     'updated_at': '2026-03-26T14:35:57-04:00'},
#    'id': 'y1797',
#    'links': {'self': '/vehicles/y1797'},
#    'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#     'stop': {'data': {'id': '93', 'type': 'stop'}},
#     'trip': {'data': {'id': '73601857', 'type': 'trip'}}},
#    'type': 'vehicle'},
#   {'attributes': {'bearing': 315,
#     'carriages': [],
#     'current_status': 'STOPPED_AT',
#     'current_stop_sequence': 10,
#     'direction_id': 0,
#     'label': '1753',
#     'latitude': 42.34141,
#     'longitude': -71.08295,
#     'occupancy_status': 'MANY_SEATS_AVAILABLE',
#     'revenue': 'REVENUE',
#     'speed': None,
#     'updated_at': '2026-03-26T14:35:59-04:00'},
#    'id': 'y1753',
#    'links': {'self': '/vehicles/y1753'},
#    'relationships': {'route': {'data': {'id': '1', 'type': 'route'}},
#     'stop': {'data': {'id': '188', 'type': 'stop'}},
#     'trip': {'data': {'id': '73601853', 'type': 'trip'}}},
#    'type': 'vehicle'}],
#  'jsonapi': {'version': '1.0'}}

# %% [markdown]
# #### Vars Used
# - `id` — vehicle_id
# - `attributes.latitude`, `attributes.longitude` — lat, lon
# - `attributes.direction_id` — direction (already 0/1, but doesn't tell me which direction that is)
# - `attributes.updated_at` — timestamp
# - `attributes.current_stop_sequence` — stop_sequence (not available in WMATA)
# - `relationships.trip.data.id` — trip_id
# - `relationships.route.data.id` — route_id
#
# #### Notes
# - No deviation field — must be computed from GTFS static feed in R
# - I'll also need GTFS static for the direction north or south bound
# - This nested unlike WMATA which was more straight forward

# %%
mbta_positions = mbta_response.json()['data']
mbta_positions

mbta_fields = []
for vehicle in mbta_positions:
    row = {
        'vehicle_id': vehicle['id'],
        'lat': vehicle['attributes']['latitude'],
        'lon': vehicle['attributes']['longitude'],
        'direction': vehicle['attributes']['direction_id'],
        'timestamp': vehicle['attributes']['updated_at'],
        'stop_sequence': vehicle['attributes']['current_stop_sequence'],
        'trip_id': vehicle['relationships']['trip']['data']['id'],
        'route_id': vehicle['relationships']['route']['data']['id']
    }
    mbta_fields.append(row)

mbta_df = pd.DataFrame(mbta_fields)
mbta_df['agency'] = 'MBTA'
mbta_df['timestamp'] = pd.to_datetime(mbta_df['timestamp'])

mbta_df
# Out:
#   vehicle_id        lat        lon  direction                 timestamp  \
# 0      y1922  42.338384 -71.074515          0 2026-03-26 14:17:19-04:00
# 1      y1902  42.336360 -71.076780          0 2026-03-26 14:17:11-04:00
# 2      y1888  42.337095 -71.077799          1 2026-03-26 14:17:20-04:00
# 3      y1871  42.370020 -71.112870          0 2026-03-26 14:17:11-04:00
# 4      y1846  42.371746 -71.117768          1 2026-03-26 14:17:18-04:00
# 5      y1828  42.349780 -71.088980          1 2026-03-26 14:17:14-04:00
# 6      y1825  42.361379 -71.096935          0 2026-03-26 14:17:19-04:00
# 7      y1797  42.332278 -71.081383          0 2026-03-26 14:17:18-04:00
# 8      y1753  42.329780 -71.083600          0 2026-03-26 14:17:13-04:00
# 9      y1742  42.337651 -71.078332          1 2026-03-26 14:17:19-04:00
#
#    stop_sequence   trip_id route_id agency
# 0              1  73604109        1   MBTA
# 1              8  73601851        1   MBTA
# 2             17  73604085        1   MBTA
# 3             22  73604092        1   MBTA
# 4              2  73604078        1   MBTA
# 5             11  73604095        1   MBTA
# 6             17  73604090        1   MBTA
# 7              3  73601857        1   MBTA
# 8              1  73601853        1   MBTA
# 9             17  73604075        1   MBTA

# %%
mbta_df.dtypes
mbta_df['timestamp'] = mbta_df['timestamp'].dt.tz_localize(None) # Making time zone consistent
mbta_df.dtypes
# Out:
# vehicle_id               object
# lat                     float64
# lon                     float64
# direction                 int64
# timestamp        datetime64[ns]
# stop_sequence             int64
# trip_id                  object
# route_id                 object
# agency                   object
# dtype: object

# %%
mbta_routes = ['1', '23', '28', '39', '57', '66']
mbta_dfs = []

for route in mbta_routes:
    mbta_response = requests.get(mbta_url, params={"filter[route]": route}, headers=mbta_headers)
    mbta_fields = []
    for vehicle in mbta_response.json()['data']:
        row = {
            'vehicle_id': vehicle['id'],
            'lat': vehicle['attributes']['latitude'],
            'lon': vehicle['attributes']['longitude'],
            'direction': vehicle['attributes']['direction_id'],
            'timestamp': vehicle['attributes']['updated_at'],
            'stop_sequence': vehicle['attributes']['current_stop_sequence'],
            'trip_id': vehicle['relationships']['trip']['data']['id'],
            'route_id': vehicle['relationships']['route']['data']['id']
        }
        mbta_fields.append(row)
    mbta_df = pd.DataFrame(mbta_fields)
    mbta_df['agency'] = 'MBTA'
    mbta_df['timestamp'] = pd.to_datetime(mbta_df['timestamp']).dt.tz_localize(None)
    mbta_dfs.append(mbta_df)

mbta_df = pd.concat(mbta_dfs, ignore_index=True)
mbta_df
# Out:
#    vehicle_id        lat        lon  direction           timestamp  \
# 0       y1922  42.333224 -71.073677          0 2026-03-26 14:45:59
# 1       y1902  42.365050 -71.103090          0 2026-03-26 14:45:58
# 2       y1871  42.341980 -71.083680          1 2026-03-26 14:45:58
# 3       y1846  42.340920 -71.082230          1 2026-03-26 14:45:56
# 4       y1828  42.332740 -71.080700          1 2026-03-26 14:45:52
# ..        ...        ...        ...        ...                 ...
# 72      y3232  42.333160 -71.101040          1 2026-03-26 14:45:38
# 73      y3224  42.329851 -71.086364          0 2026-03-26 14:45:56
# 74      y3222  42.350587 -71.131303          1 2026-03-26 14:45:32
# 75      y3209  42.328899 -71.084717          0 2026-03-26 14:45:53
# 76      y1918  42.353276 -71.134661          1 2026-03-26 14:46:04
#
#     stop_sequence   trip_id route_id agency
# 0               6  73604109        1   MBTA
# 1              18  73601851        1   MBTA
# 2              15  73604110        1   MBTA
# 3              16  73604078        1   MBTA
# 4              22  73604095        1   MBTA
# ..            ...       ...      ...    ...
# 72             29  73583989       66   MBTA
# 73              2  73583873       66   MBTA
# 74             15  73583995       66   MBTA
# 75              2  73583871       66   MBTA
# 76              5  73603240       66   MBTA
#
# [77 rows x 9 columns]

# %% [markdown]
# ### 3) MTA API
# #### Bus Routes: B44, B46, B41, Bx12, M14A, M104A

# %%
MTA_KEY = '7027c575-3c63-477c-91d8-3d404472e8a0'

# %%
mta_url = 
mta_params = 
mta_headers =
